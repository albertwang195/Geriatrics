# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
y1950 = pd.read_csv('Kaggle Data/1950.xls')
y1960 = pd.read_csv('Kaggle Data/1960.xls')
y1970 = pd.read_csv('Kaggle Data/1970.xls')
y1980 = pd.read_csv('Kaggle Data/1980.xls')
y1990 = pd.read_csv('Kaggle Data/1990.xls')
y2000 = pd.read_csv('Kaggle Data/2000.xls')
y2010 = pd.read_csv('Kaggle Data/2010.xls')

# %%
all_data = pd.concat([y1950,y1960,y1970,y1980,y1990,y2000,y2010])
y1950.year.dtype
# Out:
# dtype('int64')

# %%
all_data
# Out:
#     Number                                              title  \
# 0        1                       Put Your Head On My Shoulder
# 1        2  Whatever Will Be Will Be (Que Sera Sera) (with...
# 2        3                           Everybody Loves Somebody
# 3        4        Take Good Care Of My Baby - 1990 Remastered
# 4        5                                 A Teenager In Love
# ..     ...                                                ...
# 95      96                  Stereo Hearts (feat. Adam Levine)
# 96      97                                           Dynamite
# 97      98                                   Break Your Heart
# 98      99                                         Summer Air
# 99     100                                     All I Wanna Do
#
#                  artist        top genre  year  bpm  nrgy  dnce  dB  live  \
# 0             Paul Anka  adult standards  2000  116    34    55  -9    10
# 1             Doris Day  adult standards  1948  177    34    42 -11    72
# 2           Dean Martin  adult standards  2013   81    49    26  -9    34
# 3             Bobby Vee  adult standards  2011   82    43    49 -12    12
# 4   Dion & The Belmonts  adult standards  1959   79    38    56  -9    13
# ..                  ...              ...   ...  ...   ...   ...  ..   ...
# 95     Gym Class Heroes        dance pop  2011   90    80    65  -3    27
# 96            Taio Cruz        dance pop  2011  120    79    76  -4     3
# 97            Taio Cruz        dance pop  2011  122    89    67  -5    24
# 98        ItaloBrothers        dance pop  2017  102    75    76  -4     8
# 99        Martin Jensen         big room  2016  112    79    73  -4     7
#
#     val  dur  acous  spch  pop
# 0    47  155     75     3   72
# 1    78  123     86     4   62
# 2    40  162     81     4   61
# 3    66  151     70     6   60
# 4    62  158     67     3   60
# ..  ...  ...    ...   ...  ...
# 95   80  211      3    10   56
# 96   87  203      0     8   56
# 97   68  185      0     3   54
# 98   49  184      6     7   43
# 99   56  194     16     7   32
#
# [667 rows x 15 columns]

# %%
ols_object = smf.ols(formula = 'pop ~ bpm + nrgy + dnce + dB + live + val + dur + acous + spch', data = all_data)

model = ols_object.fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    pop   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     22.62
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):           6.11e-50
# Time:                        22:50:50   Log-Likelihood:                -2553.1
# No. Observations:                 667   AIC:                             5138.
# Df Residuals:                     651   BIC:                             5210.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     55.4579     19.797      2.801      0.005      16.583      94.332
# bpm            0.0638      0.137      0.465      0.642      -0.206       0.334
# nrgy           0.2248      0.199      1.127      0.260      -0.167       0.616
# dnce           0.0864      0.237      0.365      0.715      -0.379       0.551
# dB             0.5042      1.047      0.482      0.630      -1.552       2.560
# bpm:nrgy      -0.0015      0.001     -1.190      0.234      -0.004       0.001
# bpm:dnce       0.0013      0.001      0.950      0.342      -0.001       0.004
# bpm:dB         0.0032      0.007      0.477      0.634      -0.010       0.017
# nrgy:dnce     -0.0019      0.002     -0.975      0.330      -0.006       0.002
# nrgy:dB        0.0039      0.006      0.650      0.516      -0.008       0.016
# dnce:dB       -0.0025      0.011     -0.224      0.823      -0.025       0.020
# live          -0.0287      0.031     -0.921      0.358      -0.090       0.033
# val           -0.1133      0.023     -4.849      0.000      -0.159      -0.067
# dur            0.0409      0.008      5.212      0.000       0.026       0.056
# acous         -0.1599      0.022     -7.170      0.000      -0.204      -0.116
# spch           0.1726      0.075      2.314      0.021       0.026       0.319
# ==============================================================================
# Omnibus:                       12.142   Durbin-Watson:                   0.543
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.449
# Skew:                          -0.334   Prob(JB):                      0.00198
# Kurtosis:                       3.022   Cond. No.                     5.29e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.29e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
