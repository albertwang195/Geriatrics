# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
y1950 = pd.read_csv('1950.xls')
y1960 = pd.read_csv('1960.xls')
y1970 = pd.read_csv('1970.xls')
y1980 = pd.read_csv('1980.xls')
y1990 = pd.read_csv('1990.xls')
y2000 = pd.read_csv('2000.xls')
y2010 = pd.read_csv('2010.xls')

# %%
y1950['decade'] = 1950
y1960['decade'] = 1960
y1970['decade'] = 1970
y1980['decade'] = 1980
y1990['decade'] = 1990
y2000['decade'] = 2000
y2010['decade'] = 2010

# %%
all_data = pd.concat([y1950,y1960,y1970,y1980,y1990,y2000,y2010])
y1950.year.dtype
# Out:
# dtype('int64')

# %%
y1950.head() # some re-releases of songs show up in earlier decades, but the 'year' is a later date
#ex: Paul Anka's "Put Your Head On My Shoulder" - in 1950s, release year is 2000.
# Out:
#    Number                                              title  \
# 0       1                       Put Your Head On My Shoulder
# 1       2  Whatever Will Be Will Be (Que Sera Sera) (with...
# 2       3                           Everybody Loves Somebody
# 3       4        Take Good Care Of My Baby - 1990 Remastered
# 4       5                                 A Teenager In Love
#
#                 artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0            Paul Anka  adult standards  2000  116    34    55  -9    10   47
# 1            Doris Day  adult standards  1948  177    34    42 -11    72   78
# 2          Dean Martin  adult standards  2013   81    49    26  -9    34   40
# 3            Bobby Vee  adult standards  2011   82    43    49 -12    12   66
# 4  Dion & The Belmonts  adult standards  1959   79    38    56  -9    13   62
#
#    dur  acous  spch  pop  decade
# 0  155     75     3   72    1950
# 1  123     86     4   62    1950
# ...

# %%
y2010.corr()
# Out:
#           Number      year       bpm      nrgy      dnce        dB      live  \
# Number  1.000000 -0.419685 -0.108064  0.423453 -0.069998  0.356519  0.104397
# year   -0.419685  1.000000  0.026997 -0.404827  0.266851 -0.216683 -0.072513
# bpm    -0.108064  0.026997  1.000000  0.026813 -0.076467 -0.043644 -0.014262
# nrgy    0.423453 -0.404827  0.026813  1.000000  0.061161  0.794119  0.174272
# dnce   -0.069998  0.266851 -0.076467  0.061161  1.000000  0.132524  0.045431
# dB      0.356519 -0.216683 -0.043644  0.794119  0.132524  1.000000  0.069180
# live    0.104397 -0.072513 -0.014262  0.174272  0.045431  0.069180  1.000000
# val     0.165425 -0.202528 -0.076299  0.424567  0.387219  0.375732  0.005110
# dur     0.067154 -0.205454 -0.027527 -0.174527 -0.274811 -0.213595  0.137844
# acous  -0.246155  0.240611 -0.057103 -0.510088 -0.103396 -0.355173 -0.183309
# spch   -0.185075  0.123326  0.079919 -0.083491  0.002579 -0.280863  0.005708
# ...

# %%
all_data.corr() #popularity and decade are mildly correlated, also decade and acous decade and dB
#popularity correlated-ish with dB? acous, decade
# Out:
#           Number      year       bpm      nrgy      dnce        dB      live  \
# Number  1.000000  0.122851  0.030950  0.174730  0.046153  0.042841  0.046433
# year    0.122851  1.000000 -0.020790  0.195329  0.273865  0.422602 -0.001603
# bpm     0.030950 -0.020790  1.000000  0.179329 -0.057710  0.044748  0.009960
# nrgy    0.174730  0.195329  0.179329  1.000000  0.331962  0.702543  0.132563
# dnce    0.046153  0.273865 -0.057710  0.331962  1.000000  0.295534 -0.069818
# dB      0.042841  0.422602  0.044748  0.702543  0.295534  1.000000  0.083423
# live    0.046433 -0.001603  0.009960  0.132563 -0.069818  0.083423  1.000000
# val     0.089254 -0.087055  0.084723  0.405190  0.454714  0.136813  0.060542
# dur     0.058410 -0.099655  0.038277  0.131228  0.053011  0.026851 -0.067533
# acous  -0.074355 -0.241289 -0.175530 -0.665900 -0.382297 -0.504551 -0.056394
# spch   -0.059867  0.193292  0.059116  0.178491  0.207741  0.200195  0.091595
# ...
